# %%
import cv2
import matplotlib.pyplot as plt
from PIL import  Image
import numpy as np
test_pic=cv2.imread('nature.jpg',cv2.IMREAD_GRAYSCALE)

# %%
print(test_pic.shape)
def binary(pic,value):
    pic_height=pic.shape[0]
    pic_width=pic.shape[1]
    #二值化
    new_pic =np.zeros((pic_height,pic_width))
    for i in range (pic_height):
        for j in range(pic_width):
            if pic[i][j]>value:
                new_pic[i][j]=255
            else :
                new_pic[i][j]=0
    return new_pic
new_pic=binary(test_pic,100)
def image_negative(pic,value=0):
    pic_height=pic.shape[0]
    pic_width=pic.shape[1]
    #二值化
    new_pic =np.zeros((pic_height,pic_width))
    for i in range (pic_height):
        for j in range(pic_width):
            new_pic[i][j]=255-pic[i][j]
    return new_pic
negative_pic=image_negative(test_pic)
# Out:
# (1280, 1920)

# %%
plt.imshow(test_pic,cmap='gray')

# %%
plt.imshow(new_pic,cmap='gray')

# %%
plt.imshow(negative_pic,cmap='gray')
